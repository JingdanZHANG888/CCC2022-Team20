# %% [markdown]
# ## Twitter Harvest

# %% [markdown]
# Reference: \
# housing key words: https://www.wordstream.com/popular-keywords/real-estate-keywords?aliId=eyJpIjoiZXQwMHhlbHc5WTBEdksxSSIsInQiOiJiT01uUkVrY0M4eTFRSDh0ZWc2bG13PT0ifQ%253D%253D \
# income key words: https://www.thesaurus.com/browse/income

# %%
import datetime
import time
import json
import random
import couchdb
import tweepy
import sys
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from operator import itemgetter

nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/sicenxi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
FMT = '%Y-%m-%d %H:%M:%S'
LIMIT_IN_SEC = 900
WAIT = 60
NOW = datetime.datetime.now().strftime(FMT)

url = "http://172.26.131.170:5984"
user = "admin"
password = '170645'

# Latitude and longitude coordinates
mel_geo = '-37.840935,144.946457,200km'
syd_geo = '-33.867487,151.206990,200km'

# %%
# initialize twitter keys state
f1 = open('twitter_keys.json')
twitter_keys = json.load(f1)
current_datetime = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
for i in range(4):
    twitter_keys["keys"][i]["last_used"] = '2022-04-10 00:00:00'
a_file = open('twitter_keys.json', "w")
json.dump(twitter_keys, a_file)
a_file.close()

# read files
f2 = open('keywords.json')
keywords = json.load(f2)

# %%
def random20_keywords(key_word_file):
    # random get 20 current key words for searching
    housing_words = random.choices(key_word_file['housing'], k=10)
    income_words = random.choices(key_word_file['income'], k=10)
    mel_words = random.choices(key_word_file['Melbourne'], k=10)
    # convert these keywords into a string
    only_housing = '" OR "'.join(housing_words)
    only_housing = '"' + only_housing + '"'
    only_income = '" OR "'.join(income_words)
    only_income = '"' + only_income + '"'
    income_housing = only_housing + ' OR ' + only_income
    mel_housing = '" OR "'.join(mel_words)
    mel_housing = only_housing + ' OR "' + mel_housing + '"'
    return income_housing

# %%
def select_a_valid_twitter_key(twitter_keys_file, remove_key):
    f1 = open('twitter_keys.json')
    twitter_keys = json.load(f1)
    # get all valid twitter keys
    get_key = []
    duration_list = []
    rest_time = []
    # remove melbourne used key
    if remove_key != None:
        del twitter_keys["keys"][remove_key]
    while True:
        for valid_key in twitter_keys["keys"]:
            duration = datetime.datetime.now() - datetime.datetime.strptime(valid_key["last_used"], FMT)
            duration_in_s = duration.total_seconds()
            position = valid_key["id"] - 1
            rest_time.append(duration_in_s)
      
            if duration_in_s >= 900:
                get_key.append(valid_key)
                add_info = [duration_in_s, position]
                duration_list.append(add_info)
                
        # if there is no valid key to select, the system needs to wait
        if len(get_key) == 0:
            wait_time_in_s = LIMIT_IN_SEC - max(rest_time)
            print("Wait " + str(wait_time_in_s) + " seconds for Available Twitter key")
            time.sleep(wait_time_in_s)
            
        # if there is a valid key existing, we use the key which rests longest.
        else:
            get_key = sorted(get_key, key=lambda d: d['last_used']) 
            index = get_key[0]["id"]-1
            print("Find a valid twitter key: ", get_key[0]["id"])
            
            # get twitter API
            consumer_key = get_key[0]["detail"]["TWITTER_API_KEY"]
            consumer_secret = get_key[0]["detail"]["TWITTER_API_KEY_SECRET"]
            bearer_token = get_key[0]["detail"]["TWITTER_BEARER_TOKEN"]
            access_token = get_key[0]["detail"]["TWITTER_ACCESS_TOKEN"]
            access_token_secret = get_key[0]["detail"]["TWITTER_ACCESS_SECRET"]
            auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
            auth.set_access_token(access_token, access_token_secret)
            api = tweepy.API(auth)
                
            return api, index

# %%
def analysis_Twitter_Sentiment(text):
    sentiment = 0
    score = SentimentIntensityAnalyzer().polarity_scores(text)
    neg = score['neg']
    neu = score['neu']
    pos = score['pos']
    if neg > pos:
        sentiment = 'negative'
    elif pos > neg:
        sentiment = 'positive'
    elif pos == neg:
        sentiment = 'neutral'
    return sentiment

# %%
def harvest_tweets(tweets, dbname, key_position):
    for tweet in tweets:
            tweet_id = tweet.id
            tweet_text = tweet.text
            tweet_coord = tweet.coordinates
            tweet_place = tweet.place
            tweet_user_location = tweet.user.location
            tweet_Date = tweet.created_at.date()
            tweet_sentiment = analysis_Twitter_Sentiment(tweet_text)
            tweet_info = {'id': str(tweet_id), 
                          'content': tweet_text, 
                          'coordinates': tweet_coord, 
                          'place': str(tweet_place),
                          'user_location': tweet_user_location,
                          'created_date': str(tweet_Date),
                          'sentiment': tweet_sentiment
                         } 
    
            # add to Couchdb
            server = couchdb.Server(url)
            # Set credentials if necessary
            server.resource.credentials = (user, password)
            if dbname not in server:
                server.create(dbname)
            db = server[dbname]
            if str(tweet_info["id"]) not in db:
                tweet_info["_id"] = str(tweet_info["id"])
                db.save(tweet_info)
                print(tweet_info)
                print("Sucessfully saved to Couchdb:", dbname)
            
            # update last used time of current twitter key
            with open('twitter_keys.json', 'r') as f:
                update_key_state = json.load(f)
                keys = update_key_state['keys']
                keys[key_position]['last_used'] = datetime.datetime.now().strftime(FMT)

            with open('twitter_keys.json', 'w') as f:
                json.dump(update_key_state, f, indent=2)

# %%
# get twitter key
api, position = select_a_valid_twitter_key(twitter_keys, None)
api2, position2 = select_a_valid_twitter_key(twitter_keys, position)

# get query words
query = random20_keywords(keywords)

# get tweets
mel_tweets = tweepy.Cursor(api.search_tweets, q=query, geocode=mel_geo).items()
syd_tweets = tweepy.Cursor(api2.search_tweets, q=query, geocode=syd_geo).items()

while True:
    
    try:
        harvest_tweets(mel_tweets, "twitter_sentiment", position)
        
    except tweepy.errors.TweepyException as e:
        print("Error: ", e)
        print("Start to collect Sydney Tweets")
        # update current twitter key's state and last used time
        with open('twitter_keys.json', 'r') as f:
            update_key_state = json.load(f)
            keys = update_key_state['keys']
            keys[position]['last_used'] = datetime.datetime.now().strftime(FMT)

        with open('twitter_keys.json', 'w') as f:
            json.dump(update_key_state, f, indent=2)
        pass
    
    
    try:
        harvest_tweets(syd_tweets, "twitter_sentiment_syd", position2)
        
    except tweepy.errors.TweepyException as e:
        print("Error: ", e)
        
        # update current twitter key's state and last used time
        with open('twitter_keys.json', 'r') as f:
            update_key_state = json.load(f)
            keys = update_key_state['keys']
            keys[position2]['last_used'] = datetime.datetime.now().strftime(FMT)

        with open('twitter_keys.json', 'w') as f:
            json.dump(update_key_state, f, indent=2)
        
        # begin a new twitter API
        query = random20_keywords(keywords)
        api, position = select_a_valid_twitter_key(twitter_keys, None)
        api2, position2 = select_a_valid_twitter_key(twitter_keys, position)
        mel_tweets = tweepy.Cursor(api.search_tweets, q=query, geocode=mel_geo).items()
        syd_tweets = tweepy.Cursor(api2.search_tweets, q=query, geocode=syd_geo).items()      
        print("Start to collect Melbourne Tweets")
    except StopIteration:
        continue
# Out:
# Find a valid twitter key:  1
# Find a valid twitter key:  2
# {'id': '1524756543706595328', 'content': "@geostylegeo I don't know. I don't think you have it that bad in the US to be honest. Whenever I've been over, I'm… https://t.co/em6wxdoHWL", 'coordinates': None, 'place': 'None', 'user_location': 'Melbourne, Victoria', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524756543706595328', '_rev': '1-f19d46bcbc540354b0489d97744b0478'}
# Sucessfully saved to Couchdb: twitter_sentiment
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Start to collect Sydney Tweets
# {'id': '1524756704696553472', 'content': '@murpharoo @Myipep69Pep @BreakfastNews Are you for real? How much money do you earn PA to think a) 5.1% is an unrea… https://t.co/KGKHrXci63', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, Australia', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524756704696553472', '_rev': '1-d484e24e34ecf57e9182138f96bdf8b0'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524753009783480320', 'content': '@JoaoPra53841853 @GamestopDividen What demographics? Like how many families, average wage, that kind of thing?', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524753009783480320', '_rev': '1-46d9bd8857f9a06f624778f9934dc561'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524742062448738304', 'content': '@TimWilsonMP @GuardianAus Modern Liberals keep the coal burning, bible bashing, trans-hating, wage suppressing conservatives in power.', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524742062448738304', '_rev': '1-d30979e4fa12d54c9f3320e3a5414c5b'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524738459750989824', 'content': '@ladyrocksavage @Lorraine1935 @benryanwriter @hunterschwarz Go check the public accounts if you want receipts - Meg… https://t.co/VGVImkDkLf', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524738459750989824', '_rev': '1-4e697dda388c3f11869934ede7377947'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524737911014703104', 'content': '@john_hillam And has given himself unbelievable wage rises that could help economy', 'coordinates': None, 'place': 'None', 'user_location': 'Central Coast, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524737911014703104', '_rev': '1-08ad0eee1a34f5aba1588b9299d13a78'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524737024762445824', 'content': "Poor, poor Bridget having to deal with ScumMo - Morrison's mental health announcement upstaged by trans debate, whi… https://t.co/Qf2tLZ05Vg", 'coordinates': None, 'place': "Place(_api=<tweepy.api.API object at 0x7fc204e7e100>, id='0180d6313aa616b2', url='https://api.twitter.com/1.1/geo/id/0180d6313aa616b2.json', place_type='city', name='Wollongong', full_name='Wollongong, New South Wales', country_code='AU', country='Australia', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x7fc204e7e100>, type='Polygon', coordinates=[[[150.743944832, -34.628601669], [150.973866016, -34.628601669], [150.973866016, -34.2513407335], [150.743944832, -34.2513407335]]]), attributes={})", 'user_location': 'Wollongong, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524737024762445824', '_rev': '1-9fd1575e9e761d03fa8882748f120bc6'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524731159644864513', 'content': '@cliff_geoffrey @emma__jayne14 Worlds highest minimum wage and you talk about slaves. 💩 for 🧠.', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524731159644864513', '_rev': '1-644d51a19d2c01d8aae2c317b35a0b85'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524729096848420865', 'content': '#auspol #qanda #CostOfLiving #AusVotes\n\n#LNP bangs on about inflationary effect from $1/hr wage rise, but #RBA cont… https://t.co/kVqwYbFXVB', 'coordinates': None, 'place': 'None', 'user_location': 'Newcastle, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524729096848420865', '_rev': '1-c591297fbec35f42a80b7d1ef2ece0fa'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524727949471059968', 'content': "@DoodyDarren Rubbish. We don't have wage push inflation and we don't have the kind of catastrophic collapse in supp… https://t.co/BrEIjX5VQd", 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524727949471059968', '_rev': '1-3a725c05448731e7de831e5db1eb8380'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1
'coordinates': None, 'place': 'None', 'user_location': 'Newcastle, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524676298420809728', '_rev': '1-d20c37e71b63826c816ea723eb02fcd7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524676110356992002', 'content': "@bxxurscsQtCwBW8 @LucyDownes22 @rachelrwithers I don't need to. I'm already aware of what it is &amp; aware that a 5.1%… https://t.co/WZeP5NVjjr", 'coordinates': None, 'place': 'None', 'user_location': 'Central Coast, NSW', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524676110356992002', '_rev': '1-21aa0bddfd0072ba5a214246df36b35a'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524675643837149184', 'content': '@godcomplex96 Can probably just pay out now 🤣', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524675643837149184', '_rev': '1-9913f1956e2a7a783f4b94ca0e660c16'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524675005044297728', 'content': 'Don’t worry. Pauline will pay with her public funding.  https://t.co/8vyb5Ujbq4', 'coordinates': None, 'place': 'None', 'user_location': 'Hunter Valley NSW', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524675005044297728', '_rev': '1-9a1165e2640eeb4512ef1e973044fd0f'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524674900732309505', 'content': '@TimHarcourt @SHamiltonian @JeromeFahrer @AMWUnionActive @DougCameron51 @MattCowgill @ausbiztv @UTSEngage… https://t.co/0ZX7fAepEy', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524674900732309505', '_rev': '1-612208fb95014229eef80727ad6c6bb5'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524673475608477697', 'content': 'For goodness sake. Digging in a trash can is NOT how to find best performing stocks. Stop the nonsense. \nYou need g… https://t.co/CusnCKYVYt', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524673475608477697', '_rev': '1-0401a53bbfe0c218192399197a6c471e'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524673354451779584', 'content': '@MicheleONeilAU And Albo the millionaire socialist who on the current trends will be getting the same salary and wh… https://t.co/JTSGK0qEYz', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney Australia', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524673354451779584', '_rev': '1-4e28f9b4419d646712bf09881f5bbbfb'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524673002444849153', 'content': '@capnek123 This is NOT the question to be asking. Digging in a trash can is NOT how you find best performing stocks… https://t.co/VccOuYT46h', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524673002444849153', '_rev': '1-535df3b12bacf71457d7586bffb1ee28'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524672573250088960', 'content': 'The #LNP are trying to generate shock and horror that a Labor govt would back a CPI wage increase if granted by the… https://t.co/i16iiEaVMI', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524672573250088960', '_rev': '1-380a5475c304373bef2f99a3c6fa2c5f'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524671889569828869', 'content': "@Altgthr I'm extremely pessimistic. They are universally loathed by #MUFC's fan base who want them to sling their h… https://t.co/QfFaS3Xky5", 'coordinates': None, 'place': "Place(_api=<tweepy.api.API object at 0x7fc204e7e100>, id='0073b76548e5984f', url='https://api.twitter.com/1.1/geo/id/0073b76548e5984f.json', place_type='city', name='Sydney', full_name='Sydney, New South Wales', country_code='AU', country='Australia', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x7fc204e7e100>, type='Polygon', coordinates=[[[150.520928608, -34.1183470085], [151.343020992, -34.1183470085], [151.343020992, -33.578140996], [150.520928608, -33.578140996]]]), attributes={})", 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524671889569828869', '_rev': '1-30075d8151bb737349d7efe8e0ae2e05'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524671570249404416', 'content': 'The most appropriate currency to pay for Ivermectin is stablecoin.🐎', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524671570249404416', '_rev': '1-0ae6aebaa3b9176ccc8d350dafba90a7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524671425059356674', 'content': "@Brayster_ Some economists say that wage increases can exceed the rate of inflation, as long as it's not by too much.", 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524671425059356674', '_rev': '1-4811cf2a2d71f75e3582ac597555228e'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# ...
# {'id': '1524664435184644096', 'content': "@AmyRemeikis Just like All Australian's had to pay for the Liberald Sports &amp; Carpark Pork Barrelling, wasn't over $1B?", 'coordinates': None, 'place': "Place(_api=<tweepy.api.API object at 0x7fc204e7e100>, id='0073b76548e5984f', url='https://api.twitter.com/1.1/geo/id/0073b76548e5984f.json', place_type='city', name='Sydney', full_name='Sydney, New South Wales', country_code='AU', country='Australia', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x7fc204e7e100>, type='Polygon', coordinates=[[[150.520928608, -34.1183470085], [151.343020992, -34.1183470085], [151.343020992, -33.578140996], [150.520928608, -33.578140996]]]), attributes={})", 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524664435184644096', '_rev': '1-eb1231230b0ba2d7760d2239b436ee96'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524663640804442112', 'content': '@AustralianLabor Foolish people are falling for minimum wage antic. The guy has no economic credentials and gets hi… https://t.co/34fGhxa6iY', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, Australia', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524663640804442112', '_rev': '1-e291572409ab0439952da6c72d470c8d'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524663069330132993', 'content': "There's a clear difference between Anthony Albanese and Scott Morrison. Albo wants your pay to go up, and Morrison… https://t.co/zRBxIgAEus", 'coordinates': None, 'place': 'None', 'user_location': 'Illawarra NSW', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524663069330132993', '_rev': '1-cbd6c4a5c598e47ea5d566f52db23259'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524661645246533632', 'content': '@cathywilcox1 Once only.\nI ordered a titanium watch, they sent me a stainless steel watch. They insisted I pay $40+… https://t.co/sYolb2e7vm', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524661645246533632', '_rev': '1-ca006942f0de713558caa37e398618f6'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524661518377586690', 'content': 'On the day that @CricketAus raised the average domestic wage for female cricketers playing WBBL and WNCL to $86,000… https://t.co/B3OwXuMFSn', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524661518377586690', '_rev': '1-884645f352cd2b0ee6a72644c7756b63'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524660416625790977', 'content': 'Don\'t mean to bash it when it\'s down, but my firm view is that the intrinsic value of any crypto not backed by a "r… https://t.co/zau9ZS0BrB', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524660416625790977', '_rev': '1-d2617682650a545384b229fc2c38a151'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524659654797627392', 'content': 'Factcheck: is Albanese’s backing of a 5.1% minimum wage rise an ‘unprecedented’ intervention? | Australian election… https://t.co/n0JrFNHkEE', 'coordinates': None, 'place': 'None', 'user_location': 'Newcastle, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524659654797627392', '_rev': '1-addbf6c19ca679831a4bbfef0fde0fa8'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524657893945257984', 'content': '@AnastasiosManol @DavidGr07837209 Good luck if you vote for Labor.\nTax Increase will counter the Wage Rise.', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524657893945257984', '_rev': '1-5d4ea3df66a88011e091731c01f0815c'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524656963044487168', 'content': 'Factcheck: is Albanese’s backing of a 5.1% minimum wage rise an ‘unprecedented’ intervention? | Australian election… https://t.co/PlCvpauKjW', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, Australia', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524656963044487168', '_rev': '1-ce19e18fed362707b10e95e51ddbb038'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524650712570888192', 'content': '@SquizzSTK Great ABC news! Clearly highlights that LNP low wage growth policy is economically dangerous!!', 'coordinates': None, 'place': 'None', 'user_location': 'Camden, Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524650712570888192', '_rev': '1-e25cc2ce20a1b227bc1fe2c873de5988'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524650609315524611', 'content': '@terencehuynh Wage increases absolutely increase inflation. But the idea that minimum wage should not automatically… https://t.co/ZdoPTeiOg2', 'coordinates': None, 'place': "Place(_api=<tweepy.api.API object at 0x7fc204e7e100>, id='0073b76548e5984f', url='https://api.twitter.com/1.1/geo/id/0073b76548e5984f.json', place_type='city', name='Sydney', full_name='Sydney, New South Wales', country_code='AU', country='Australia', contained_within=[], bounding_box=BoundingBox(_api=<tweepy.api.API object at 0x7fc204e7e100>, type='Polygon', coordinates=[[[150.520928608, -34.1183470085], [151.343020992, -34.1183470085], [151.343020992, -33.578140996], [150.520928608, -33.578140996]]]), attributes={})", 'user_location': 'Melbourne, Australia', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524650609315524611', '_rev': '1-58f042392777da1bb5cf73208f97de6e'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524650332735045632', 'content': 'Today Albo clarified what he meant...\nThe 200k+ workers on $20.33 an hour should get 5.1%⬆️, not the 2.5million+ wo… https://t.co/MtsYHJKoDl', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, NSW, Australia ', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524650332735045632', '_rev': '1-e621451b7d6d98a3c8d6cf9474a3a970'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524649022707105792', 'content': '@murpharoo @Paul_Karp Albo pledged to support an increase in the minimum wage by 5.1% - no if, no buts, nothing. \nT… https://t.co/pEfLgQ4f2C', 'coordinates': None, 'place': 'None', 'user_location': 'Central Coast, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524649022707105792', '_rev': '1-af9184b5fa791baa295e48a81624b8e7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Find a valid twitter key:  3
# Find a valid twitter key:  4
# Start to collect Melbourne Tweets
# {'id': '1524750086634602496', 'content': '@TalkingWolves @alex_crook @talkSPORT If they get 15 million very sad that a very good striker was cut down in his… https://t.co/2w9TVFeB4Z', 'coordinates': None, 'place': 'None', 'user_location': 'Melbourne, Victoria', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524750086634602496', '_rev': '1-d9e2a92d5fba3fb2fcb23e553e1ef6cb'}
# Sucessfully saved to Couchdb: twitter_sentiment
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Start to collect Sydney Tweets
# {'id': '1524758851970801665', 'content': 'Sugar daddy pls pay for my surgery', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524758851970801665', '_rev': '1-9852f9895e7e5f6a3ca36e9372f730f3'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524757660356255746', 'content': '@0xab12 @peter1337_ @Regulars_NFT It does indeed i almost went for mint price but thrn i realised initially in anno… https://t.co/PI05uoZMIf', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney , Australia', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524757660356255746', '_rev': '1-c9a0b738406501c32d0cdbfb1fadc7f7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524757626621288448', 'content': "The PM won't talk to him because the PM doesn't serve Australians. So arrogant and pompous! Don't forget that tax p… https://t.co/HUZyQZ53ce", 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524757626621288448', '_rev': '1-f9f6200dc1620f9f6b17a15fff7a309f'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524757460099256320', 'content': '@Lee_NUFC93 @ConnorY89938475 @The_Looney_Toon Yeah they’ve been terrible and his injury was an impact one not a mus… https://t.co/CijdkHxz0X', 'coordinates': None, 'place': 'None', 'user_location': 'Newcastle', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524757460099256320', '_rev': '1-567680a3253cf201a2f87afd918589a7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524737660652191744', 'content': '@SmasherBondi @jodyjsperling This new follow paying dividends already 😂', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524737660652191744', '_rev': '1-bcc6f1405bf7387920c7e673ee916e58'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524690002071879682', 'content': '@LeeSixnine It was not knee jerk, it was to protect the product and ecosystem by making the benefits more sustainab… https://t.co/eVBNwNDrNw', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524690002071879682', '_rev': '1-650d0ceec6b5e9a44904bffa32301ec4'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524687900566163456', 'content': 'Yoshitha Rajapakse, son of deposed Sri Lankan PM, has allegedly travelled to Aust with proceeds of corruption most… https://t.co/LJPat2aVFg', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524687900566163456', '_rev': '1-73ac19313667bc07384990bc0139c049'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524687144228311040', 'content': '@TimHoran12 With the greatest respect to you (favourite player ever) and the game, I hope so. However the empirical… https://t.co/5VkUkWZXe3', 'coordinates': None, 'place': 'None', 'user_location': 'Coogee, Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524687144228311040', '_rev': '1-49d468224805788b6f6ca7975918c5d3'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524679896554897408', 'content': "@ChairDoge @Azriel_Shaolin @SwipeWright Complicity does mean they're running it. If society benefits one group over… https://t.co/VzA78NRIro", 'coordinates': None, 'place': 'None', 'user_location': 'Sydney', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524679896554897408', '_rev': '1-54bb81e0511b5ca8561ec4058c8643d5'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524679458459947011', 'content': '@labour_history For some, benefits should be at a punitive level, punishing people for being poor, disabled, unemployed', 'coordinates': None, 'place': 'None', 'user_location': 'Newcastle', 'created_date': '2022-05-12', 'sentiment': 'negative', '_id': '1524679458459947011', '_rev': '1-1cc1fced754fea7f3925f203528dc6d4'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524673665241317376', 'content': '@SanghiPablo1 Pratek mahina 1000 kiwa 1.5k jasa Jamel tas Mutual fund madhe invest kara, salary wadhli ki 2 kiwa 3k… https://t.co/gZJwNWy54J', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524673665241317376', '_rev': '1-992c9de9c0d1572c3a316b75a03a6c17'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524669539673288704', 'content': "Benefits of masks debunked all over the world but if you catch the train home in Australia they're everywhere. Pointless.", 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524669539673288704', '_rev': '1-7640753f48f8d6ce1d8f4143491b453a'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524668715039858688', 'content': '@DjentBeard Bro yes. Doubled my salary this year and financial freedom hits DIFFERENT', 'coordinates': None, 'place': 'None', 'user_location': 'Newcastle, Australia', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524668715039858688', '_rev': '1-944f29efb09b97353f67c78486e5f6c4'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524668061957373952', 'content': '@erpardeepjain I guess working alone as opposed to working as a salaried employee doesn’t help either. Almost 1/3rd… https://t.co/nImaQFDNnq', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524668061957373952', '_rev': '1-473278b0fed25ad45294d64cd0a8e483'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524663873353043968', 'content': '@BethRobrahn sharing the joy, health and well-being benefits of a cycling in a 15 minute neighbourhood living in Be… https://t.co/yc9aWBk8iS', 'coordinates': None, 'place': 'None', 'user_location': 'Wollongong, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524663873353043968', '_rev': '1-eab09a7db1b818ba1e9bc3621ddca0f7'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524663609460023296', 'content': '🇨🇦 Wouldn’t it be nice to start out again fresh in League One, spending the full salary cap and playing home games… https://t.co/2eC7FqdsMt', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524663609460023296', '_rev': '1-4f00ae1157138653b7407af517bd205f'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524662001926090753', 'content': 'New #job: ACCOUNTANT JUNIOR Location: Clayton Salary: AU$65kpa - AU$75kpa .. https://t.co/o7E8E7sNLj #jobs #hiring', 'coordinates': None, 'place': 'None', 'user_location': 'Melbourne and Sydney Australia', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524662001926090753', '_rev': '1-7d7d2dd35051757f3f20d15a100e3138'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524659994435604480', 'content': '@Mufc_AS @Hamhed23 @UTDNicolass @amitttrmfc Messi’s salary was out of this world to the point where La Liga couldn’… https://t.co/BAdmYK7AR4', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'neutral', '_id': '1524659994435604480', '_rev': '1-87169f19e4808d775d182d0eb653deb6'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# {'id': '1524658369650253825', 'content': 'Factors to be considered when choosing good dividend stocks.\nFollow us for more investing tips.\n\n#dividends… https://t.co/EA7AhRmyNR', 'coordinates': None, 'place': 'None', 'user_location': 'Sydney, New South Wales', 'created_date': '2022-05-12', 'sentiment': 'positive', '_id': '1524658369650253825', '_rev': '1-548cb60e2aab681dd3ed5715c49e6dab'}
# Sucessfully saved to Couchdb: twitter_sentiment_syd
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Find a valid twitter key:  1
# Find a valid twitter key:  2
# Start to collect Melbourne Tweets
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Start to collect Sydney Tweets
# Error:  429 Too Many Requests
# 88 - Rate limit exceeded
# Find a valid twitter key:  3
# Wait 737.723842 seconds for Available Twitter key
# Find a valid twitter key:  4
# Start to collect Melbourne Tweets
